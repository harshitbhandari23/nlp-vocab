# %% [markdown]
# <a href="https://colab.research.google.com/github/harshitbhandari23/nlp-vocab/blob/main/vocab_using_tensor_flow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
tk=Tokenizer()

# %%
corpus=["cofee is hot","Water is cold"]

# %%
tk.fit_on_texts(corpus)

# %%
tk.index_word
# Out:
# {1: '<ovv>', 2: 'is', 3: 'cofee', 4: 'hot', 5: 'water', 6: 'cold'}

# %%
tk.texts_to_sequences(corpus)
# Out:
# [[2, 1, 3], [4, 1, 5]]

# %% [markdown]
# # handling unseen words

# %%
tk=Tokenizer(oov_token='<ovv>')
tk.fit_on_texts(corpus)

# %%
tk.index_word
# Out:
# {1: '<ovv>', 2: 'is', 3: 'cofee', 4: 'hot', 5: 'water', 6: 'cold'}

# %%
corpus1=["black cofee is hot","Pure water is cold"]

# %%
tk.texts_to_sequences(corpus1)
# Out:
# [[1, 3, 2, 4], [1, 5, 2, 6]]
